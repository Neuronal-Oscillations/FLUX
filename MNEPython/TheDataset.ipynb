# %% [markdown]
# # The data set
#
#
# ## Introduction
#
# To demonstrate the functionality of the pipeline we will be using an MEG dataset based on a spatial attention paradigm. The paradigm is derived from a study involving moving gratings and the detection of subtle dots (based on Grent-’t-Jong et al., 2018 and Hoogenboom et al., 2006; see Figure 1). The main advantage of this task is that the allocation of spatial attention produces robust modulations in the 8 – 12 Hz alpha band during the cue-grating interval. Furthermore, the moving gratings will induce strong activity in the 60 – 90 Hz gamma band.
#
#
# ## The MEG system
#
# The data were recorded using the MEGIN TRIUX system, installed in 2018 at the [Centre for Human Brain Health](https://www.birmingham.ac.uk/research/centre-for-human-brain-health/index.aspx). The TRIUX system has 306 sensors distributed over the head: 204 planar gradiometers and 102 magnetometers (noise-resilient ARMOR sensors). The MEG system is placed in a shielded room (2 layers of mu-metal and 1 layer of aluminium).  The system allows for concurrent electroencephalography (EEG) recordings from 64 electrodes as well as bipolar sensors. The system also allows for continuous monitoring of the head position.
#
# The peripherals of the MEG system applied to record the dataset include:
#
# * ProPixx visual projector (1440 Hz refresh rate)
# * EyeLink 1000 Plus fast eye-tracker
# * NAtA button boxes
# * EOG and ECG recordings
# * Stimulus delivery computer using Matlab/Psychtoolbox
#
# Please see "The Introduction" for where to find the data.
#
#
#
# ## The paradigm
# Trials started with a fixation dot followed by a cue pointing to the left or right (Figure 1). This indicated to the participants which of the two upcoming stimuli to attend. After a 1 s interval, two inward moving circular gratings were shown in both hemifields. After a random interval (1 – 3.5 s) a white dot was presented for 50 ms at the centre of the grating in the cued hemifield. Participants were instructed to press a button (right index finger) as soon as they detected the dot. The stimuli presentation were implemented in Matlab using the Psychophysics Toolbox (Brainard, 1997) and the code can be found on the FLUX website.
#
#
# ![paradigm.png](attachment:paradigm.png)
# **Figure 1.** *The paradigm used for the MEG data collection in the FLUX pipeline. A cue directs the participants to attend left or right. This results in strong hemispheric lateralization of the posterior alpha power (8 – 12 Hz). Then follows the presentation of the moving gratings which will induce strong gamma power (60 – 90 Hz) in the visual cortex as well as visual evoked fields. Finally, the button response to the dot flash will result in gamma band activity in the motor cortex followed by suppression in the beta band (15 – 40 Hz). Since the task produces robust and well-documented modulations in the alpha, beta and gamma band as well as event-related fields it is well suited for the FLUX pipeline with a focus on the characterization of oscillatory brain activity in the visual and motor regions as well as source modelling.*
#
#
# **Question 1:** How might the alpha band and gamma band activity specifically be modulated with respect to left versus right  directed attention?
#
# **Question 2:** In which brain regions might the strongest modulation of alpha and gamma activity be expected?
#
# **Question 3:** Provide examples of event-related fields generated and modulated by the various task components.
#
#
# ## Preregistration and publication
#
#
# Publication example. Describe the relevant parameters of the tasks:
#
# "Each trial started with a fixation dot followed by a cue pointing to the left or right (Figure 1). This indicated to the participants which of the two upcoming stimuli to attend. After a 1 s interval, two inward moving circular gratings were shown in both hemifields. After a random interval (1 – 3.5 s) a white dot was presented for 50ms at the centre of the grating in the cued hemifield. Participants were instructed to press a button (right index finger) as soon as they detected the dot. The moving gratings were centred at +/- 4 degrees. They were each 2 degrees wide. In total 100 trials were presented to each participant. In 50% of the trials, the participants were randomly cued either to the left or right. The stimuli presentation was implemented in Matlab using the Psychophysics Toolbox (Brainard, 1997).  "
#
#
# ## References
#
#
# * Grent-’t-Jong, T., Rivolta, D., Gross, J., Gajwani, R., Lawrie, S.M., Schwannauer, M., Heidegger, T., Wibral, M., Singer, W., Sauer, A., Scheller, B., Uhlhaas, P.J., 2018. Acute ketamine dysregulates task-related gamma-band oscillations in thalamo-cortical circuits in schizophrenia. Brain 141, 2511–2526.
# * Hoogenboom, N., Schoffelen, J.-M., Oostenveld, R., Parkes, L.M., Fries, P., 2006. Localizing human visual gamma-band activity in frequency, time and space. Neuroimage 29, 764–773.
# * Jensen, O., and Hanslmayr, S., 2020. The Role of Alpha Oscillations for Attention and Working Memory. In. Poeppel, D., Mangun, G.R., and Gazzaniga, M.S. (eds) The cognitive neurosciences, 6th MIT Press.
# * Brainard, D.H., 1997. The Psychophysics Toolbox. Spat Vis 10, 433–436.
